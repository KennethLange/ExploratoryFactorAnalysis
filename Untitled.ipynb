# %%
using ExploratoryFactorAnalysis

# 1. 生成测试数据 (n=200, p=50, r=3)
(S, Y) = GenerateRandomData(200, 50, 3)

# 2. 运行 Gauss-Newton 算法
(L, d, iters) = FactorAnalysisGN(S, 3)

# 3. 打印结果
println("Converged in $iters iterations")
display(L[1:5, :]) # 显示前5行的 Loadings

# 4. 或者直接运行全量测试
RunTests(1.0)
# Out:
# ArgumentError: Package ExploratoryFactorAnalysis not found in current path.
# - Run `import Pkg; Pkg.add("ExploratoryFactorAnalysis")` to install the ExploratoryFactorAnalysis package.
